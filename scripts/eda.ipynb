# %% [markdown]
# # EDA

# %%
import os # download required packages 
os.environ["CUDA_VISIBLE_DEVICES"] = "-1"

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("../data/metadata") # read csv
image_dir = "data/images"

df["image_path"] = df["image_id"].apply(
    lambda x: os.path.join(image_dir, x + ".jpg")
) # create full image path 

df.head()
# Out:
#      lesion_id      image_id   dx dx_type   age   sex localization  \
# 0  HAM_0000118  ISIC_0027419  bkl   histo  80.0  male        scalp
# 1  HAM_0000118  ISIC_0025030  bkl   histo  80.0  male        scalp
# 2  HAM_0002730  ISIC_0026769  bkl   histo  80.0  male        scalp
# 3  HAM_0002730  ISIC_0025661  bkl   histo  80.0  male        scalp
# 4  HAM_0001466  ISIC_0031633  bkl   histo  75.0  male          ear
#
#         dataset                    image_path
# 0  vidir_modern  data/images/ISIC_0027419.jpg
# 1  vidir_modern  data/images/ISIC_0025030.jpg
# 2  vidir_modern  data/images/ISIC_0026769.jpg
# 3  vidir_modern  data/images/ISIC_0025661.jpg
# 4  vidir_modern  data/images/ISIC_0031633.jpg

# %% [markdown]
# # Class Distribution

# %%
df["dx"].value_counts().plot(kind="bar")
plt.title("Class Distribution")
plt.xlabel("Types of Pigmented Lesions")
plt.ylabel("Count")
plt.savefig("../outputs/EDA/class_distribution.png", bbox_inches="tight")
plt.close() # distribution of lesion class

# %% [markdown]
# # Age Distribution

# %%
plt.hist(df["age"].dropna(), bins=30)
plt.title("Age Distribution")
plt.xlabel("Age")
plt.ylabel("Count")
plt.savefig("../outputs/EDA/age_distribution.png", bbox_inches="tight")
plt.close() # distribution of age

# %% [markdown]
# # Sex Distribution

# %%
df["sex"].value_counts().plot(kind="bar")
plt.title("Sex Distribution")
plt.xlabel("Sex")
plt.ylabel("Count")
plt.savefig("../outputs/EDA/sex_distribution.png", bbox_inches="tight")
plt.close() # distribution of sex

# %% [markdown]
# # Localization Distribution

# %%
df["localization"].value_counts().plot(kind="bar")
plt.title("Lesion Localization")
plt.xlabel("Localization")
plt.ylabel("Count")
plt.xticks(rotation=90)
plt.savefig("../outputs/EDA/localization_distribution.png", bbox_inches="tight")
plt.close() # distribution of localization

# %% [markdown]
# # Heatmap

# %%
pivot = pd.crosstab(df["localization"], df["dx"])

plt.figure(figsize=(10, 6))
sns.heatmap(pivot, annot=True, fmt="d", cmap="YlGnBu")

plt.title("Localization vs Diagnosis Heatmap")
plt.xlabel("Diagnosis (dx)")
plt.ylabel("Localization")

plt.tight_layout()
plt.savefig("../outputs/EDA/localization_vs_dx_heatmap.png", bbox_inches="tight")
plt.close() # heatmap of localization vs dx (lesion class)

# %%
pivot = pd.crosstab(df["age"], df["dx"])

plt.figure(figsize=(10, 6))
sns.heatmap(pivot, annot=True, fmt="d", cmap="YlGnBu")

plt.title("Age vs Diagnosis Heatmap")
plt.xlabel("Diagnosis (dx)")
plt.ylabel("Age")

plt.tight_layout()
plt.savefig("../outputs/EDA/age_vs_dx_heatmap.png", bbox_inches="tight")
plt.close() # heatmap of age vs dx

# %%
pivot = pd.crosstab(df["sex"], df["dx"])

plt.figure(figsize=(10, 6))
sns.heatmap(pivot, annot=True, fmt="d", cmap="YlGnBu")

plt.title("Localization vs Diagnosis Heatmap")
plt.xlabel("Diagnosis (dx)")
plt.ylabel("Sex")

plt.tight_layout()
plt.savefig("../outputs/EDA/sex_vs_dx_heatmap.png", bbox_inches="tight")
plt.close() # heatmap of sex vs dx
